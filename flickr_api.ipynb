# %%
import flickrapi
import pandas as pd
import time

# %%
api_key = u'9167a49cfce881f8712c26d6542fbc51'
api_secret = u'4dfb057a1d42faaa'
flickr = flickrapi.FlickrAPI(api_key, api_secret)

# %%
df = pd.DataFrame({'id': [], 'lat': [], 'lon': []})

# %%
for photo in flickr.walk(per_page=1,tag_mode='all',tags='alps,swiss,rock',
                         min_taken_date='2018-07-01',max_taken_date='2018-09-30',extras="geo"):
    print (photo.attrib['id'])
    #print (photo.attrib['latitude'])
    #print (photo.attrib['longitude'])

# %%
for photo in flickr.walk(per_page=1,tag_mode='any',tags='alps,swiss,rocks',
                         min_taken_date='2018-07-01',max_taken_date='2018-09-30',extras="geo"):
    try:
        df = df.append({'id': photo.attrib['id'], 'lat': photo.attrib['latitude'], 'lon': photo.attrib['longitude']}, ignore_index=True)
        time.sleep(1)
    except FlickrError:
        time.sleep(30)
# Out:
# do_request: Status code 500 received, content:
# ---------------------------------------------------------------------------
# FlickrError                               Traceback (most recent call last)
# <ipython-input-23-abf930c802be> in <module>
#       1 for photo in flickr.walk(per_page=1,tag_mode='any',tags='alps,swiss,rocks',
# ----> 2                          min_taken_date='2018-07-01',max_taken_date='2018-09-30',extras="geo"):
#       3     try:
#       4         df = df.append({'id': photo.attrib['id'], 'lat': photo.attrib['latitude'], 'lon': photo.attrib['longitude']}, ignore_index=True)
#       5         time.sleep(1)
#
# D:\Softwares\Python_Anaconda\Anaconda3\envs\rockfall\lib\site-packages\flickrapi\core.py in data_walker(self, method, searchstring, **params)
#     686             LOG.debug('Calling %s(page=%i of %i, %s)' %
#     687                       (method.__name__, page, total, params))
# --> 688             rsp = method(page=page, **params)
#     689
# ...

# %%
df
# Out:
#               id        lat         lon
# 0    46018000484          0           0
# 1    46689743062          0           0
# 2    46729292301          0           0
# 3    46670776562          0           0
# 4    39751071433          0           0
# 5    46638629192          0           0
# 6    46559997092          0           0
# 7    45682617395          0           0
# 8    32599562418          0           0
# 9    31506733567          0           0
# 10   45508894765          0           0
# 11   46358922992          0           0
# 12   45445458675          0           0
# 13   45445417685          0           0
# 14   32368461718          0           0
# 15   32334572348          0           0
# 16   45418327164          0           0
# 17   32129418738          0           0
# 18   45200585654          0           0
# 19   44586670205          0           0
# 20   31439128688          0           0
# 21   43345580860          0           0
# ...

# %%
df_clean = df[df['lat'].map(len) > 1]

# %%
export_csv = df_clean.to_csv ('./flickr_locations.csv', index = None, header=True)

# %%
"https://www.flickr.com/search/?sort=date-taken-desc&media=photos&min_taken_date=1530396000&max_taken_date=1538344799&view_all=1&advanced=1&text=swiss%20alps%20rocks"
# Out:
# 'https://www.flickr.com/search/?sort=date-taken-desc&media=photos&min_taken_date=1530396000&max_taken_date=1538344799&view_all=1&advanced=1&text=swiss%20alps%20rocks'
